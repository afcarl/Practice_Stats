# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
import numpy as np

# %%
from stats import *

# %%
main()
# Out:
# Location Age Histograms
# Location Heart Rate & Cholesterol Box Plots
# Blood Pressure Histogram Comparison
# Probability Density Function
# KS Test Distributions
#
# D_stat =
#  0.160215053763 P_val =  0.793072973711
# The distributions are the same =  True
